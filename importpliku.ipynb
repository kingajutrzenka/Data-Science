# %% [markdown]
# <a href="https://colab.research.google.com/github/kingajutrzenka/Data-Science/blob/main/importpliku.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
def fetch_financial_data(company='AMZN'):
    """
    This function fetch stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

df = fetch_financial_data('META')
df.head()
# Out:
#                Open      High      Low   Close    Volume
# Date
# 2025-07-14  717.600  728.0000  716.547  720.92   8939399
# 2025-07-11  722.495  725.1600  709.700  717.51  10873880
# 2025-07-10  731.550  735.7999  719.600  727.24   9922249
# 2025-07-09  722.715  737.5300  722.715  732.78  11417963
# 2025-07-08  721.570  722.9099  714.810  720.67   7770693

# %%
df.Open.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#zapis danych
df.to_csv('fb.csv')

# %%
df_nov = df[(df.index.month == 11) & (df.index.year == 2021)] # wycinamy danymiesiąc i rok
df_nov
# Out:
#                 Open      High      Low   Close    Volume
# Date
# 2021-11-30  335.0000  335.8100  323.430  324.46  25390008
# 2021-11-29  336.8900  340.6700  335.305  338.03  16650949
# 2021-11-26  335.7950  337.7500  331.902  333.12  14750737
# 2021-11-24  336.0000  341.7800  332.810  341.06  13566181
# 2021-11-23  338.9300  341.3999  333.500  337.25  17224986
# 2021-11-22  349.0500  353.8300  340.510  341.01  27116811
# 2021-11-19  342.2000  352.1000  339.900  345.30  26488541
# 2021-11-18  339.7200  342.4600  335.300  338.69  17487235
# 2021-11-17  344.2400  347.3000  340.100  340.77  13602812
# 2021-11-16  343.8300  346.6500  340.870  342.96  18181106
# 2021-11-15  344.3400  353.6500  343.200  347.56  25076603
# 2021-11-12  330.1800  341.8600  329.780  340.89  25414311
# 2021-11-11  329.8200  332.4590  327.000  327.74  12376563
# 2021-11-10  332.4900  333.1900  325.510  327.64  21872605
# 2021-11-09  340.0000  341.3075  334.470  335.37  17556721
# ...

# %%
df_nov.to_csv('fb_nov.csv')

# %%
new_df = pd.read_csv('fb_nov.csv')
new_df
# Out:
#           Date      Open      High      Low   Close    Volume
# 0   2021-11-30  335.0000  335.8100  323.430  324.46  25390008
# 1   2021-11-29  336.8900  340.6700  335.305  338.03  16650949
# 2   2021-11-26  335.7950  337.7500  331.902  333.12  14750737
# 3   2021-11-24  336.0000  341.7800  332.810  341.06  13566181
# 4   2021-11-23  338.9300  341.3999  333.500  337.25  17224986
# 5   2021-11-22  349.0500  353.8300  340.510  341.01  27116811
# 6   2021-11-19  342.2000  352.1000  339.900  345.30  26488541
# 7   2021-11-18  339.7200  342.4600  335.300  338.69  17487235
# 8   2021-11-17  344.2400  347.3000  340.100  340.77  13602812
# 9   2021-11-16  343.8300  346.6500  340.870  342.96  18181106
# 10  2021-11-15  344.3400  353.6500  343.200  347.56  25076603
# 11  2021-11-12  330.1800  341.8600  329.780  340.89  25414311
# 12  2021-11-11  329.8200  332.4590  327.000  327.74  12376563
# 13  2021-11-10  332.4900  333.1900  325.510  327.64  21872605
# ...

# %%
# export do excela
df_nov.to_excel('fb_nov.xlsx')

# %%
new_df = pd.read_excel('fb_nov.xlsx', index_col=0) #index_col daje nam date od razu a nie numeruje indexy (0, 1,...)
new_df
# Out:
#                 Open      High      Low   Close    Volume
# Date
# 2021-11-30  335.0000  335.8100  323.430  324.46  25390008
# 2021-11-29  336.8900  340.6700  335.305  338.03  16650949
# 2021-11-26  335.7950  337.7500  331.902  333.12  14750737
# 2021-11-24  336.0000  341.7800  332.810  341.06  13566181
# 2021-11-23  338.9300  341.3999  333.500  337.25  17224986
# 2021-11-22  349.0500  353.8300  340.510  341.01  27116811
# 2021-11-19  342.2000  352.1000  339.900  345.30  26488541
# 2021-11-18  339.7200  342.4600  335.300  338.69  17487235
# 2021-11-17  344.2400  347.3000  340.100  340.77  13602812
# 2021-11-16  343.8300  346.6500  340.870  342.96  18181106
# 2021-11-15  344.3400  353.6500  343.200  347.56  25076603
# 2021-11-12  330.1800  341.8600  329.780  340.89  25414311
# 2021-11-11  329.8200  332.4590  327.000  327.74  12376563
# 2021-11-10  332.4900  333.1900  325.510  327.64  21872605
# 2021-11-09  340.0000  341.3075  334.470  335.37  17556721
# ...

# %% [markdown]
# **London Bike Dataset**

# %%
df_lbd = pd.read_csv('london-bike.csv')
df_lbd.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1254 entries, 2025-07-14 to 2020-07-16
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    1254 non-null   float64
#  1   High    1254 non-null   float64
#  2   Low     1254 non-null   float64
#  3   Close   1254 non-null   float64
#  4   Volume  1254 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.8 KB

# %%
#tworzenie indexu
df_lbd = df_lbd.set_index('timestamp')
df_lbd.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0
# 2015-01-04 01:00:00         0.0         1.0     3.0
# 2015-01-04 02:00:00         0.0         1.0     3.0
# 2015-01-04 03:00:00         0.0         1.0     3.0
# 2015-01-04 04:00:00         0.0         1.0     3.0

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df_lbd)
# Out:
# https://docs.google.com/spreadsheets/d/1f1QgBQwsWVe4kPb92FNOJJEZC7MuMKQ_9Zg701AB2sQ/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1f1QgBQwsWVe4kPb92FNOJJEZC7MuMKQ_9Zg701AB2sQ/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
