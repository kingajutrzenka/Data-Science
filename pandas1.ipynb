# %% [markdown]
# <a href="https://colab.research.google.com/github/kingajutrzenka/Data-Science/blob/main/pandas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# nauka pandas

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %%
df = pd.DataFrame(data=[[10, 12, 13],[23, 12, 10]], index = ['first', 'second'], columns = ['col_1', 'col_2', 'col_3'])
print(df)
# Out:
#         col_1  col_2  col_3
# first      10     12     13
# second     23     12     10

# %%
#tak wycinamy daną kolumnę:
df['col_1']
# Out:
# first     10
# second    23
# Name: col_1, dtype: int64

# %%
type(df['col_1']) #series to jedna kolumna
# Out:
# pandas.core.series.Series

# %%
df[['col_1']] # w ten sposób mamy dataframe

# %%
df.columns = ['a', 'b', 'c']
df
# w ten sposób zmeiniamy nazwy kolumn
# Out:
#          a   b   c
# first   10  12  13
# second  23  12  10

# %%
print(df)
# Out:
#          a   b   c
# first   10  12  13
# second  23  12  10

# %%
#pokazywanie kolumn
df.b
#ale gdy nie ma spacji
# Out:
# first     12
# second    12
# Name: b, dtype: int64

# %%
# tworzenie kolumny d
df['d'] = df.a + df.c
df
# Out:
#          a   b   c   d
# first   10  12  13  23
# second  23  12  10  33
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['a'].plot(kind='hist', bins=20, title='a')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['c'].plot(kind='hist', bins=20, title='c')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['d'].plot(kind='hist', bins=20, title='d')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='a', y='c', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
df.loc['first'] # wycina pierwszy wiersz
# Out:
# a    10
# b    12
# c    13
# d    23
# Name: first, dtype: int64

# %%
df.iloc[0]
# Out:
# a    10
# b    12
# c    13
# d    23
# Name: first, dtype: int64

# %% [markdown]
# możemy też tworzyć "przecięcia"

# %%
df.loc['first', 'a']
# Out:
# np.int64(10)

# %%
df.loc[:, 'a']
# Out:
# first     10
# second    23
# Name: a, dtype: int64

# %%
df.iloc[0, 0]
# Out:
# np.int64(10)
