# %% [markdown]
# <a href="https://colab.research.google.com/github/kingajutrzenka/Data-Science/blob/main/%C5%81%C4%85czenie_danych.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
def fetch_financial_data(company='AMZN'):
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

    apple = fetch_financial_data('AAPL')
    amazon = fetch_financial_data('AMZN')
    google = fetch_financial_data('GOOGL')
    uber = fetch_financial_data('UBER')

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1254 entries, 2025-07-15 to 2020-07-17
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   apple_apple_apple_open    1254 non-null   float64
#  1   apple_apple_apple_high    1254 non-null   float64
#  2   apple_apple_apple_low     1254 non-null   float64
#  3   apple_apple_apple_close   1254 non-null   float64
#  4   apple_apple_apple_volume  1254 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.8 KB

# %%
google.head()
# Out:
#             google_google_google_open  google_google_google_high  \
# Date
# 2025-07-15                     182.81                     184.22
# 2025-07-14                     181.01                     183.67
# 2025-07-11                     176.78                     181.43
# 2025-07-10                     175.63                     178.43
# 2025-07-09                     175.25                     179.44
#
#             google_google_google_low  google_google_google_close  \
# Date
# 2025-07-15                    181.60                      182.00
# 2025-07-14                    179.68                      181.56
# 2025-07-11                    176.48                      180.19
# 2025-07-10                    174.38                      177.62
# 2025-07-09                    172.77                      176.62
#
#             google_google_google_volume
# Date
# 2025-07-15                     33448251
# 2025-07-14                     32536632
# 2025-07-11                     34282922
# 2025-07-10                     29252386
# 2025-07-09                     43025594

# %%
uber.describe().T
# Out:
#          count        mean         std        min         25%         50%  \
# Open   1254.00       50.15       18.32      20.37       34.12       46.53
# High   1254.00       51.04       18.50      21.13       34.80       47.47
# Low    1254.00       49.25       18.10      19.89       33.30       45.86
# Close  1254.00       50.16       18.31      20.46       34.07       46.55
# Volume 1254.00 23789521.50 16298141.11 5200356.00 15581061.00 20119213.00
#
#                75%          max
# Open         66.03        97.50
# High         67.22        97.72
# Low          65.05        96.10
# Close        66.02        97.48
# Volume 27712245.00 364261230.00

# %%
# dodajemy do nazwy każdej kolumny nazwę firmy
apple.columns = ['apple_' + col.lower() for col in apple.columns]
uber.clumns = ['uber_' + col.lower() for col in uber.columns]
amazon.columns = ['amazon_' + col.lower() for col in amazon.columns]
google.columns = ['google_' + col.lower() for col in google.columns]

# %%
apple.head(10)
# Out:
#             apple_apple_apple_apple_open  apple_apple_apple_apple_high  \
# Date
# 2025-07-15                        209.22                        211.89
# 2025-07-14                        209.93                        210.91
# 2025-07-11                        210.56                        212.13
# 2025-07-10                        210.50                        213.48
# 2025-07-09                        209.53                        211.33
# 2025-07-08                        210.10                        211.43
# 2025-07-07                        212.68                        216.23
# 2025-07-03                        212.15                        214.65
# 2025-07-02                        208.91                        213.34
# 2025-07-01                        206.66                        210.19
#
#             apple_apple_apple_apple_low  apple_apple_apple_apple_close  \
# Date
# 2025-07-15                       208.92                         209.11
# 2025-07-14                       207.54                         208.62
# 2025-07-11                       209.86                         211.16
# 2025-07-10                       210.03                         212.41
# 2025-07-09                       207.22                         211.14
# 2025-07-08                       208.45                         210.01
# 2025-07-07                       208.80                         209.95
# 2025-07-03                       211.81                         213.55
# 2025-07-02                       208.14                         212.44
# 2025-07-01                       206.14                         207.82
#
#             apple_apple_apple_apple_volume
# Date
# 2025-07-15                        42296339
# 2025-07-14                        38840111
# 2025-07-11                        39765812
# 2025-07-10                        44443635
# 2025-07-09                        48749367
# 2025-07-08                        42848928
# 2025-07-07                        50228984
# 2025-07-03                        34955836
# 2025-07-02                        67941811
# 2025-07-01                        78788867

# %%
mix = pd.concat(objs=[apple, amazon, uber, google], axis=1) # w ten sposób łączymy wszystkie kolumny
mix.head()
# Out:
#             apple_apple_apple_apple_open  apple_apple_apple_apple_high  \
# Date
# 2025-07-15                        209.22                        211.89
# 2025-07-14                        209.93                        210.91
# 2025-07-11                        210.56                        212.13
# 2025-07-10                        210.50                        213.48
# 2025-07-09                        209.53                        211.33
#
#             apple_apple_apple_apple_low  apple_apple_apple_apple_close  \
# Date
# 2025-07-15                       208.92                         209.11
# 2025-07-14                       207.54                         208.62
# 2025-07-11                       209.86                         211.16
# 2025-07-10                       210.03                         212.41
# 2025-07-09                       207.22                         211.14
#
#             apple_apple_apple_apple_volume  amazon_amazon_amazon_amazon_open  \
# Date
# 2025-07-15                        42296339                            226.20
# 2025-07-14                        38840111                            225.07
# 2025-07-11                        39765812                            223.58
# 2025-07-10                        44443635                            221.55
# 2025-07-09                        48749367                            221.07
#
#             amazon_amazon_amazon_amazon_high  amazon_amazon_amazon_amazon_low  \
# Date
# 2025-07-15                            227.27                           225.46
# 2025-07-14                            226.66                           224.24
# 2025-07-11                            226.68                           222.37
# 2025-07-10                            222.79                           219.70
# 2025-07-09                            224.29                           220.47
#
#             amazon_amazon_amazon_amazon_close  \
# Date
# 2025-07-15                             226.35
# 2025-07-14                             225.69
# 2025-07-11                             225.02
# 2025-07-10                             222.26
# 2025-07-09                             222.54
#
#             amazon_amazon_amazon_amazon_volume  Open  High   Low  Close  \
# Date
# 2025-07-15                            34907294 95.00 95.16 91.85  92.21
# 2025-07-14                            35702597 95.30 95.48 93.56  93.89
# 2025-07-11                            50518307 96.12 96.83 95.27  95.39
# 2025-07-10                            30370591 96.07 97.45 95.12  96.40
# 2025-07-09                            38155121 97.50 97.72 96.10  96.64
#
#               Volume  google_google_google_google_open  \
# Date
# 2025-07-15  18488377                            182.81
# 2025-07-14  14300220                            181.01
# 2025-07-11  12453518                            176.78
# 2025-07-10  15650890                            175.63
# 2025-07-09  14858918                            175.25
#
#             google_google_google_google_high  google_google_google_google_low  \
# Date
# 2025-07-15                            184.22                           181.60
# 2025-07-14                            183.67                           179.68
# 2025-07-11                            181.43                           176.48
# 2025-07-10                            178.43                           174.38
# 2025-07-09                            179.44                           172.77
#
#             google_google_google_google_close  \
# Date
# 2025-07-15                             182.00
# 2025-07-14                             181.56
# 2025-07-11                             180.19
# 2025-07-10                             177.62
# 2025-07-09                             176.62
#
#             google_google_google_google_volume
# Date
# 2025-07-15                            33448251
# 2025-07-14                            32536632
# 2025-07-11                            34282922
# 2025-07-10                            29252386
# 2025-07-09                            43025594

# %%
mix.describe().T
# Out:
#                                      count        mean         std  \
# apple_apple_apple_apple_open       1254.00      167.13       36.65
# apple_apple_apple_apple_high       1254.00      169.00       36.91
# apple_apple_apple_apple_low        1254.00      165.39       36.48
# apple_apple_apple_apple_close      1254.00      167.29       36.74
# apple_apple_apple_apple_volume     1254.00 79719407.17 41462670.29
# amazon_amazon_amazon_amazon_open   1254.00      156.98       34.55
# amazon_amazon_amazon_amazon_high   1254.00      158.88       34.67
# amazon_amazon_amazon_amazon_low    1254.00      154.93       34.36
# amazon_amazon_amazon_amazon_close  1254.00      156.94       34.55
# amazon_amazon_amazon_amazon_volume 1254.00 62174249.06 29335046.18
# Open                               1254.00       50.15       18.32
# High                               1254.00       51.04       18.50
# Low                                1254.00       49.25       18.10
# Close                              1254.00       50.16       18.31
# Volume                             1254.00 23789521.50 16298141.11
# google_google_google_google_open   1254.00      129.83       31.25
# google_google_google_google_high   1254.00      131.34       31.49
# google_google_google_google_low    1254.00      128.41       30.95
# google_google_google_google_close  1254.00      129.89       31.22
# google_google_google_google_volume 1254.00 32220534.37 13719565.62
#
#                                            min         25%         50%  \
# apple_apple_apple_apple_open             88.56      140.08      164.91
# apple_apple_apple_apple_high             90.49      141.67      166.74
# apple_apple_apple_apple_low              86.77      138.40      163.50
# apple_apple_apple_apple_close            90.15      140.18      164.90
# apple_apple_apple_apple_volume     23260251.00 51828313.75 69919913.00
# amazon_amazon_amazon_amazon_open         82.80      132.00      160.43
# amazon_amazon_amazon_amazon_high         83.48      133.60      162.25
# amazon_amazon_amazon_amazon_low          81.43      130.44      158.61
# amazon_amazon_amazon_amazon_close        81.82      131.93      160.34
# amazon_amazon_amazon_amazon_volume 15007497.00 42371090.25 55639022.50
# Open                                     20.37       34.12       46.53
# High                                     21.13       34.80       47.47
# Low                                      19.89       33.30       45.86
# Close                                    20.46       34.07       46.55
# Volume                              5200356.00 15581061.00 20119213.00
# google_google_google_google_open         69.88      104.24      130.78
# google_google_google_google_high         71.64      105.64      132.13
# google_google_google_google_low          69.85      103.29      129.15
# google_google_google_google_close        70.21      104.38      130.53
# google_google_google_google_volume  9346519.00 23363734.50 28848681.00
#
#                                            75%          max
# apple_apple_apple_apple_open            190.42       257.91
# apple_apple_apple_apple_high            192.35       259.81
# apple_apple_apple_apple_low             189.51       257.35
# apple_apple_apple_apple_close           190.76       258.74
# apple_apple_apple_apple_volume     94106653.75 384545982.00
# amazon_amazon_amazon_amazon_open        178.12       239.01
# amazon_amazon_amazon_amazon_high        180.10       242.52
# amazon_amazon_amazon_amazon_low         176.24       238.03
# amazon_amazon_amazon_amazon_close       178.39       242.06
# amazon_amazon_amazon_amazon_volume 73720180.00 272661720.00
# Open                                     66.03        97.50
# High                                     67.22        97.72
# Low                                      65.05        96.10
# Close                                    66.02        97.48
# Volume                             27712245.00 364261230.00
# google_google_google_google_open        151.19       203.39
# google_google_google_google_high        153.22       207.05
# google_google_google_google_low         149.84       202.81
# google_google_google_google_close       151.37       206.38
# google_google_google_google_volume 36653970.75 127747554.00

# %%
mix.columns
# Out:
# Index(['apple_apple_apple_apple_open', 'apple_apple_apple_apple_high',
#        'apple_apple_apple_apple_low', 'apple_apple_apple_apple_close',
#        'apple_apple_apple_apple_volume', 'amazon_amazon_amazon_amazon_open',
#        'amazon_amazon_amazon_amazon_high', 'amazon_amazon_amazon_amazon_low',
#        'amazon_amazon_amazon_amazon_close',
#        'amazon_amazon_amazon_amazon_volume', 'Open', 'High', 'Low', 'Close',
#        'Volume', 'google_google_google_google_open',
#        'google_google_google_google_high', 'google_google_google_google_low',
#        'google_google_google_google_close',
#        'google_google_google_google_volume'],
#       dtype='object')

# %%
closes = [col for col in mix.columns if col.endswith('close') or col.endswith('volume')] # volumen - ilość akcji sprzedanych
closes
# Out:
# ['apple_apple_apple_apple_close',
#  'apple_apple_apple_apple_volume',
#  'amazon_amazon_amazon_amazon_close',
#  'amazon_amazon_amazon_amazon_volume',
#  'google_google_google_google_close',
#  'google_google_google_google_volume']

# %%
mix[closes].corr() #korelacja
# Out:
#                                     apple_apple_apple_apple_close  \
# apple_apple_apple_apple_close                                1.00
# apple_apple_apple_apple_volume                              -0.54
# amazon_amazon_amazon_amazon_close                            0.54
# amazon_amazon_amazon_amazon_volume                          -0.52
# google_google_google_google_close                            0.87
# google_google_google_google_volume                          -0.12
#
#                                     apple_apple_apple_apple_volume  \
# apple_apple_apple_apple_close                                -0.54
# apple_apple_apple_apple_volume                                1.00
# amazon_amazon_amazon_amazon_close                            -0.11
# amazon_amazon_amazon_amazon_volume                            0.60
# google_google_google_google_close                            -0.50
# google_google_google_google_volume                            0.30
#
#                                     amazon_amazon_amazon_amazon_close  \
# apple_apple_apple_apple_close                                    0.54
# apple_apple_apple_apple_volume                                  -0.11
# amazon_amazon_amazon_amazon_close                                1.00
# amazon_amazon_amazon_amazon_volume                              -0.33
# google_google_google_google_close                                0.73
# google_google_google_google_volume                              -0.11
#
#                                     amazon_amazon_amazon_amazon_volume  \
# apple_apple_apple_apple_close                                    -0.52
# apple_apple_apple_apple_volume                                    0.60
# amazon_amazon_amazon_amazon_close                                -0.33
# amazon_amazon_amazon_amazon_volume                                1.00
# google_google_google_google_close                                -0.51
# google_google_google_google_volume                                0.45
#
#                                     google_google_google_google_close  \
# apple_apple_apple_apple_close                                    0.87
# apple_apple_apple_apple_volume                                  -0.50
# amazon_amazon_amazon_amazon_close                                0.73
# amazon_amazon_amazon_amazon_volume                              -0.51
# google_google_google_google_close                                1.00
# google_google_google_google_volume                              -0.15
#
#                                     google_google_google_google_volume
# apple_apple_apple_apple_close                                    -0.12
# apple_apple_apple_apple_volume                                    0.30
# amazon_amazon_amazon_amazon_close                                -0.11
# amazon_amazon_amazon_amazon_volume                                0.45
# google_google_google_google_close                                -0.15
# google_google_google_google_volume                                1.00

# %% [markdown]
# **drugi sposób na łączenie dancyh - metoda concat()**

# %%
uber.head()
# Out:
#             Open  High   Low  Close    Volume
# Date
# 2025-07-15 95.00 95.16 91.85  92.21  18488377
# 2025-07-14 95.30 95.48 93.56  93.89  14300220
# 2025-07-11 96.12 96.83 95.27  95.39  12453518
# 2025-07-10 96.07 97.45 95.12  96.40  15650890
# 2025-07-09 97.50 97.72 96.10  96.64  14858918

# %%
uber_6 = uber[uber.index.month == 6]
uber_7 = uber[uber.index.month == 7]

# %%
uber67 = pd.concat([uber_6, uber_7])
uber67.head()
# Out:
#             Open  High   Low  Close    Volume
# Date
# 2025-06-30 91.69 93.39 91.52  93.30  16155270
# 2025-06-27 91.86 92.51 89.97  91.53  24731168
# 2025-06-26 91.30 94.38 90.88  93.12  23657765
# 2025-06-25 91.56 92.89 90.60  90.90  17400840
# 2025-06-24 87.99 92.48 87.91  91.65  38925080
